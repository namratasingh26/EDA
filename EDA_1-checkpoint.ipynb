# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Sale_dataset.csv")
df.shape
# Out:
# (550068, 12)

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
df.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3631
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               20
# Product_Category_2               17
# Product_Category_3               15
# Purchase                      18105
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
df['Product_Category_2']=df['Product_Category_2'].fillna('0')
df['Product_Category_3']=df['Product_Category_3'].fillna('0')
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Product_Category_2            0
# Product_Category_3            0
# Purchase                      0
# dtype: int64

# %%
df['Age']=df['Age'].map({'0-17':'Teenager','18-25':'Adult','26-35':'Adult','36-45':'Adult','46-50':'Adult','51-55':'Old','55+':'Old'})
df.head()
# Out:
#    User_ID Product_ID Gender       Age  Occupation City_Category  \
# 0  1000001  P00069042      F  Teenager          10             A
# 1  1000001  P00248942      F  Teenager          10             A
# 2  1000001  P00087842      F  Teenager          10             A
# 3  1000001  P00085442      F  Teenager          10             A
# 4  1000002  P00285442      M       Old          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#   Product_Category_2 Product_Category_3  Purchase
# 0                  0                  0      8370
# 1                6.0               14.0     15200
# ...

# %%
corelation = df.corr()
sns.heatmap(corelation, xticklabels=corelation.columns,yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Occupation',data=df)
# Out:
# <AxesSubplot:xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.countplot(x='Age',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
df['Purchase'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
cp=df.groupby('Gender')['Purchase'].count()
cp.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Gender'>

# %%
ap=df.groupby('Age')['Purchase'].count()
ap.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
ap=df.groupby('Marital_Status')['Purchase'].count()
ap.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Marital_Status'>

# %%
sp=df.groupby('Stay_In_Current_City_Years')['Purchase'].count()
sp.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Stay_In_Current_City_Years'>

# %%
pp1=df.groupby('Product_Category_1')['Purchase'].count()
pp1.nlargest(5).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_Category_1'>

# %%
pp2=df.groupby('Product_Category_2')['Purchase'].count()
pp2.nlargest(5).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_Category_2'>

# %%
pp3=df.groupby('Product_Category_3')['Purchase'].count()
pp3.nlargest(5).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Product_Category_3'>

# %%
a=df['Product_Category_1'].value_counts().nlargest(5)
sns.barplot(x=a.index,y=a)
# Out:
# <AxesSubplot:ylabel='Product_Category_1'>

# %%
b=df['Product_Category_2'].value_counts().nlargest(5)
sns.barplot(x=b.index,y=b)
# Out:
# <AxesSubplot:ylabel='Product_Category_2'>

# %%
c=df['Product_Category_3'].value_counts().nlargest(5)
sns.barplot(x=c.index,y=c)
# Out:
# <AxesSubplot:ylabel='Product_Category_3'>
